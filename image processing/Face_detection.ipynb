# %%
import cv2
cascPath = "haarcascade_frontalface_default.xml"

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('faces.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))
# Out:
# Found 7 faces!

# %%
import matplotlib.pyplot as plt

# %%
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

#plt.imshow("Faces found", image)
imgplot = plt.imshow(image)
#plt.show()
plt.savefig('faces_rect.jpg',dpi=800)

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('abba.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))
# Out:
# Found 4 faces!

# %%
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

#plt.imshow("Faces found", image)
imgplot = plt.imshow(image)
#plt.show()
plt.savefig('abba_rect.jpg',dpi=800)

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('durga.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))
# Out:
# Found 1 faces!

# %%
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

#plt.imshow("Faces found", image)
imgplot = plt.imshow(image)
#plt.show()
plt.savefig('durga_rect.jpg',dpi=800)

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('ssc.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))
# Out:
# Found 3 faces!

# %%
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

#plt.imshow("Faces found", image)
imgplot = plt.imshow(image)
#plt.show()
plt.savefig('ssc_rect.jpg',dpi=800)

# %% [markdown]
# # Example

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('dp pan2.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)


print("Found {0} faces!".format(len(faces)))
# Out:
# Found 2 faces!

# %% [markdown]
# # crop the image-see the face

# %%
faces[0] #array([132, 334, 194, 194], dtype=int32)
# Out:
# array([132, 334, 194, 194], dtype=int32)

# %%
print(faces[0][0])
face_0 = image[faces[0][1]:faces[0][1]+faces[0][3],faces[0][0]:faces[0][0]+faces[0][2]]#image[334:528,132:326]
plt.imshow(face_0)
# Out:
# 132

# %%
faces[1]
# Out:
# array([1133,  367,   79,   79], dtype=int32)

# %%
face_1 = image[faces[1][1]:faces[1][1]+faces[1][3],faces[1][0]:faces[1][0]+faces[1][2]]#image[367:442, 1133:1212]
plt.imshow(face_1)

# %%
# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
print(type(image))
#plt.imshow("Faces found", image)
plt.imshow(image)
#plt.show()
plt.savefig('dp pan2_rect.jpg',dpi=800)
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Example

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)
# Read the image
image = cv2.imread('group_photo.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
    #flags = cv2.CV_HAAR_SCALE_IMAGE
)


print("Found {0} faces!".format(len(faces)))
# Out:
# Found 4 faces!

# %%
#Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
print(type(image))
#plt.imshow("Faces found", image)
plt.imshow(image)
#plt.show()
plt.savefig('group_photo_rect.jpg',dpi=800)
# Out:
# <class 'numpy.ndarray'>
